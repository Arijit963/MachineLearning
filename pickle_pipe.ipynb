# %%
import numpy as np
import pandas as pd
import pickle

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current working directory:", current_directory)

# Load the model from the current working directory
file_path = os.path.join(current_directory, "pipe.pkl")
pipe = pickle.load(open(file_path, "rb"))
# Out:
# Current working directory: /content

# %%
test_input2 = np.array([1, "female", 31.0, 0, 0, 10.5, "S"], dtype=object).reshape(1, 7)
test_input2_df = pd.DataFrame(test_input2, columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
pipe.predict(test_input2_df)
# Out:
# array([1])
